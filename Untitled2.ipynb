# %%
import pandas as pd
import Chefboost as chef

# %%
df = pd.read_csv("liver dataset convert.csv")
display(df)
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     50                9                 2                   202
# 1     66              173                85                   388
# 2     47               35                16                   206
# 3     57               45                23                   315
# 4     52                8                 2                   245
# ..   ...              ...               ...                   ...
# 515   75                9                 2                   162
# 516   42                7                 2                   197
# 517   64                3                14                   248
# 518   23               23                 8                   509
# 519   74                1                 3                   175
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          20                          26              72
# 1                         173                         367              78
# 2                          32                          31              68
# 3                         120                         105               7
# 4                          48                          49              64
# ..                        ...                         ...             ...
# 515                        25                          20              69
# 516                        64                          33              58
# 517                        46                          40              65
# 518                        28                          44              69
# 519                        30                          32              64
#
#      Albumin  Albumin_and_Globulin_Ratio decision
# 0         45                         166    liver
# 1         26                           5    liver
# 2         34                           1    liver
# 3          4                          13    liver
# 4         32                           1    liver
# ..       ...                         ...      ...
# 515       37                          11    liver
# 516       24                           7   normal
# 517       32                           9    liver
# 518       29                           7   normal
# 519       34                          11    liver
#
# [520 rows x 10 columns]

# %%
config =  {'algorithm': 'C4.5', 'enableParallelism': False, 'boosting': 'adaboost'}
model = chef.fit(df.copy(), config=config, target_label = 'decision')
# Out:
# C4.5  tree is going to be built...
# Adaboosting:  33%|████████████████████████▎                                                | 1/3 [00:04<00:08,  4.48s/it]
# perubahan di rumus alpha dibagi 2
# 0.8943674845641459 tot new weiight
# 1.0 sum weight
# 0      0.002150
# 1      0.002150
# 2      0.002150
# 3      0.002150
# 4      0.002150
#          ...
# 515    0.002150
# 516    0.001324
# 517    0.002150
# 518    0.001324
# 519    0.002150
# Name: New_Weights, Length: 520, dtype: float64 new weight
# Adaboosting:  67%|████████████████████████████████████████████████▋                        | 2/3 [00:20<00:11, 11.10s/it]
# perubahan di rumus alpha dibagi 2
# 0.9023456752802951 tot new weiight
# 0.9999999999999998 sum weight
# 0      0.002383
# 1      0.002383
# 2      0.002383
# 3      0.002383
# 4      0.002383
#          ...
# 515    0.002383
# 516    0.000707
# 517    0.002383
# 518    0.000707
# 519    0.002383
# Name: New_Weights, Length: 520, dtype: float64 new weight
# Adaboosting: 100%|█████████████████████████████████████████████████████████████████████████| 3/3 [00:38<00:00, 12.71s/it]
# perubahan di rumus alpha dibagi 2
# 0.9174180217047561 tot new weiight
# 1.0 sum weight
# 0      0.002597
# 1      0.002597
# 2      0.002597
# 3      0.002597
# 4      0.002597
#          ...
# 515    0.002597
# 516    0.000308
# 517    0.001037
# 518    0.000308
# 519    0.002597
# Name: New_Weights, Length: 520, dtype: float64 new weight
# -------------------------
# finished in  38.140114545822144  seconds
# masuk sini [{'prediction': 'liver', 'alpha': 1}]
# epoch 0
# masuk sini [{'prediction': 'liver', 'alpha': 1}, {'prediction': 'liver', 'alpha': 1}]
# epoch 1
# masuk sini [{'prediction': 'liver', 'alpha': 1}, {'prediction': 'liver', 'alpha': 1}, {'prediction': 'liver', 'alpha': 1}]
# epoch 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12724\200892927.py in <module>
#       1 config =  {'algorithm': 'C4.5', 'enableParallelism': False, 'boosting': 'adaboost'}
# ----> 2 model = chef.fit(df.copy(), config=config, target_label = 'decision')
#
# D:\Kuliah Things\skripsi\kodingan skripsi\Chefboost.py in fit(df, config, target_label, validation_df)
#     295         df = base_df.copy()
#     296         # df['Decision'] = df['Decision'].astype(str)
# --> 297         evaluate(obj, df, task = 'train')
#     298         #validation set accuracy
#     299         if isinstance(validation_df, pd.DataFrame):
#
# D:\Kuliah Things\skripsi\kodingan skripsi\Chefboost.py in evaluate(model, df, target_label, task)
#     622         #--------------------------
#     623
# --> 624         functions.bulk_prediction(df, model)
#     625
#     626         enableAdaboost = model["config"]["enableAdaboost"]
#
# D:\Kuliah Things\skripsi\kodingan skripsi\commons\functions.py in bulk_prediction(df, model)
#      13         for index, instance in df.iterrows():
#      14                 features = instance.values[0:-1]
# ---> 15                 prediction = cb.predict(model, features)
#      16                 predictions.append(prediction)
#      17
#
# D:\Kuliah Things\skripsi\kodingan skripsi\Chefboost.py in predict(model, param)
#     425
#     426                         #find the most frequent prediction
# --> 427                         (values, counts) = np.unique(predictions, return_counts=True)
#     428                         idx = np.argmax(counts)
#     429                         prediction = values[idx]
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'
